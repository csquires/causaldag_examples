# %%
import causaldag as cd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
nnodes = 10
d = cd.rand.directed_erdos(nnodes, exp_nbrs=2)

# %%
basis = [np.cos, np.sin, np.exp]
s = cd.rand.rand_additive_basis(
    d, 
    basis,
    rand_weight_fn=lambda size: 10*np.ones(size), noise=lambda: np.random.laplace(0, 1)
)
samples = s.sample(100)

# %%
plt.scatter(samples[:, 0], samples[:, 1]);

# %%
d = cd.DAG(arcs={(1, 2), (2, 3), (1, 3)})
basis = [np.sin, np.cos, np.exp]
snr_dict = {1: 9/10, 2: 9/10}
g = cd.rand.rand_additive_basis(d, basis, snr_dict)
samples = g.sample(100)

# %%
plt.scatter(samples[:, 0], samples[:, 1]);

# %%
plt.scatter(samples[:, 0], samples[:, 2]);

# %%
plt.scatter(samples[:, 1], samples[:, 2]);
